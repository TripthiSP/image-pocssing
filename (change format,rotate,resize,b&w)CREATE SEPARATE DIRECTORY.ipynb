# %%
from PIL import Image
import os

os.getcwd()
# Out:
# 'C:\\Users\\User\\image processing'

# %%
# Let us import one image in our Jupyter environment and open that in the notebook itself

image1 = Image.open("flower2.jpg")

image1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=221x228 at 0x2217B07BE80>

# %%
image1.show()

# %%
#changing file type
image1.save("pic1.png")
print('image saved succesfully')
# Out:
# image saved succesfully

# %%
# lists all the files and folders in the current working directory
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'baby.jpg',
#  'bag.png',
#  'bc.jfif',
#  'bg.jfif',
#  'bg.jpg',
#  'butterfly.png',
#  'cat.jpg',
#  'cat2.jpg',
#  'cat_damaged.png',
#  'cat_inpainted.png',
#  'cat_mask.png',
#  'cat_msk.png',
#  'cctt.jpg',
#  'cleaned.png',
#  'contour image.ipynb',
#  'crop.png',
#  'dice contour.ipynb',
#  'dice.jpg',
#  'dice1.jpg',
#  'dice1.png',
#  'dice3.jpg',
#  'Dice4.png',
#  'dice5.png',
#  'dicec.png',
#  'Display name of image.ipynb',
#  'dm.png',
#  'dn1.jfif',
#  'dn2.jfif',
#  'dog.jpg',
#  'dot.jpg',
#  'ein.jfif',
#  'einstin.png',
#  'entire folder negative.ipynb',
#  'f.png',
#  'flower.png',
#  'flower2.jpg',
#  'flr1.jfif',
#  'football.png',
#  'frame image.ipynb',
#  'fruit.jpg',
#  'fruits.jpg',
#  'fruits_sharpen.jpg',
#  'g.jpeg',
#  'g2.jpg',
#  'gfg_dummy_pic.png',
#  'girl.jfif',
#  'girl.jpg',
#  'gmg.jpg',
#  'im1.jpg',
#  'im1.png',
#  'im2.jpg',
#  'im2.png',
#  'im3.jpg',
#  'im4.jpg',
#  'Image restoration.py',
#  'img manipulation.ipynb',
#  'img.png',
#  'img2.png',
#  'imgd.jpg',
#  'imm1.png',
#  'intensity transformation.ipynb',
#  'interpolation nois histogram.ipynb',
#  'kk.png',
#  'lines.jpg',
#  'logo.png',
#  'mask.jpg',
#  'me.png',
#  'modified img manipulation.ipynb',
#  'modified negative.ipynb',
#  'montage.ipynb',
#  'montage.png',
#  'moon.jpg',
#  'my.png',
#  'nature.jpg',
#  'night.jpg',
#  'noisy.png',
#  'noisy2.png',
#  'OIP.jpg',
#  'peppers.png',
#  'pic1.png',
#  'pizza2.png',
#  'pizza_bluescreen.jpg',
#  'rectangle.png',
#  'remove logo,adding noise,segmentation.ipynb',
#  'restorstion damaged image.ipynb',
#  'rotate_output.jpg',
#  'sample.ipynb',
#  'sample2.ipynb',
#  'sb.jpg',
#  'sci.jpg',
#  'skimage_montage_default.jpg',
#  'space_background.jpg',
#  'star.jpg',
#  't1.png',
#  't2.png',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'Untitled5.ipynb',
#  'Untitled6.ipynb',
#  'watermark removal.ipynb',
#  'watermark.jpg']

# %%
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        print(fn, "&", fext)
# Out:
# baby & .jpg
# bg & .jpg
# cat & .jpg
# cat2 & .jpg
# cctt & .jpg
# dice & .jpg
# dice1 & .jpg
# dice3 & .jpg
# dog & .jpg
# dot & .jpg
# flower2 & .jpg
# fruit & .jpg
# fruits & .jpg
# fruits_sharpen & .jpg
# g2 & .jpg
# girl & .jpg
# gmg & .jpg
# im1 & .jpg
# im2 & .jpg
# im3 & .jpg
# im4 & .jpg
# imgd & .jpg
# lines & .jpg
# mask & .jpg
# moon & .jpg
# nature & .jpg
# night & .jpg
# OIP & .jpg
# pizza_bluescreen & .jpg
# rotate_output & .jpg
# sb & .jpg
# sci & .jpg
# skimage_montage_default & .jpg
# space_background & .jpg
# star & .jpg
# watermark & .jpg

# %%
#Looping over the image files
for f in os.listdir("."):
    if f.endswith(".jpg"):
        print(f)
# Out:
# baby.jpg
# bg.jpg
# cat.jpg
# cat2.jpg
# cctt.jpg
# dice.jpg
# dice1.jpg
# dice3.jpg
# dog.jpg
# dot.jpg
# flower2.jpg
# fruit.jpg
# fruits.jpg
# fruits_sharpen.jpg
# g2.jpg
# girl.jpg
# gmg.jpg
# im1.jpg
# im2.jpg
# im3.jpg
# im4.jpg
# imgd.jpg
# lines.jpg
# mask.jpg
# moon.jpg
# nature.jpg
# night.jpg
# OIP.jpg
# pizza_bluescreen.jpg
# rotate_output.jpg
# sb.jpg
# sci.jpg
# skimage_montage_default.jpg
# space_background.jpg
# star.jpg
# watermark.jpg

# %%
# Creating new Directory using OS library
os.mkdir('NewExtnsn1')
print('Directory created')
# Note: If you already have a directory with this name, you will get error.
# Out:
# Directory created

# %%
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        i.save("NewExtnsn1/{}.pdf".format(fn))
print('check the directory')
# Out:
# check the directory

# %%
# Creating new multiple Directories using OS library
os.makedirs('resize//small')
os.makedirs('resize//tiny')
print('created')
# Note: If you already have a directory with this name, you will get error.
# Out:
# created

# %%
size_small = (600,600) # small images of 600 X 600 pixels
size_tiny = (200,200)  # tiny images of 200 X 200 pixels
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        i.thumbnail(size_small)
        i.save("resize/small/{}_small{}".format(fn, fext))
        i.thumbnail(size_tiny)
        i.save("resize/tiny/{}_tiny{}".format(fn, fext))
print('check the directory')
# Out:
# check the directory

# %%
image2 = Image.open("flower2.jpg")
image2 = image2.convert(mode='L')
image2
# Out:
# <PIL.Image.Image image mode=L size=221x228 at 0x2217DB8F2E0>

# %%
# Creating new Directory using OS library
os.mkdir('b&w')
print('Created')
# Out:
# Created

# %%
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        im = i.convert(mode = 'L')
        im.save("b&w/{}_bw.{}".format(fn, fext))
print('Look into the b&w folder')
# Out:
# Look into the b&w folder

# %%
#rotating the image to 55 Degree angle
image3 = Image.open("cat.jpg")
image3.rotate(55).save("image3.jpg")
Image3 = Image.open("image3.jpg")
Image3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=339x508 at 0x2217DFA3520>

# %%
# Creating new Directory using OS library
os.mkdir('rotate')
print('created')
# Out:
# created

# %%
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        im = i.rotate(90)
        im.save("rotate/{}_rot.{}".format(fn, fext))
print('Look into the rotate folder')
# Out:
# Look into the rotate folder
