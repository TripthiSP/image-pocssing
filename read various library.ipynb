# %%
from skimage import color
from skimage import io
import matplotlib.pyplot as plt
read_image=io.imread('flower.jpg')
plt.imshow(read_image)
plt.show()

# %%
img=color.rgb2gray(read_image)
io.imsave("skimage_gray.png",img)
io.imshow(img)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
from PIL import Image
img=Image.open('flower.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x720 at 0x22E256179A0>

# %%
img=Image.open('flower.jpg').convert('L')
img.save('pil_grayscale.png')
img
# Out:
# <PIL.Image.Image image mode=L size=960x720 at 0x22E23A401C0>

# %%
import matplotlib.pyplot as plt
img=plt.imread('flower.jpg')
plt.imshow(img)
plt.show()

# %%
plt.imshow(img,cmap='gray')
