# %%
from skimage import color
from skimage import io
import matplotlib.pyplot as plt
read_image=io.imread('flower2.jpg')
plt.imshow(read_image)
plt.show()

# %%
img=color.rgb2gray(read_image)
io.imsave("flower2.jpg",img)
io.imshow(img)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
from PIL import Image
img=Image.open('flower2.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=221x228 at 0x1A13820F5E0>

# %%
img=Image.open('flower2.jpg').convert('L')
img.save('pil_grayscale.png')
img
# Out:
# <PIL.Image.Image image mode=L size=221x228 at 0x1A1381337F0>

# %%
import matplotlib.pyplot as plt
img=plt.imread('flower2.jpg')
plt.imshow(img)
plt.show()

# %%
plt.imshow(img,cmap='gray')
