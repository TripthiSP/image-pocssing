# %%
from PIL import Image
im=Image.open('flower2.jpg')
angle=45
out=im.rotate(angle,expand=True)
out.save('rotate_output.jpg')
out
# Out:
# <PIL.Image.Image image mode=RGB size=319x318 at 0x21B8CEF96A0>

# %%
#resize
from PIL import Image
filepath='flower2.jpg'
img=Image.open(filepath)
img.show()
new_image=img.resize((300,200))
new_image
# Out:
# <PIL.Image.Image image mode=RGB size=300x200 at 0x21B8D253340>

# %%
#quantization
import cv2
from PIL import Image
image=Image.open('flower2.jpg')
image.show()
img=image.quantize(19)
img
# Out:
# <PIL.Image.Image image mode=P size=221x228 at 0x21B896B1880>

# %%
from PIL import Image
from PIL import ImageDraw
import matplotlib.pyplot as plt
img = Image.open('mrng.jpg')
d1 = ImageDraw.Draw(img)
font = ImageFont.truetype("arial",50)
d1.text((90,90),"GOOD MORNING", fill=(255, 0, 0),font=font)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x408 at 0x21B892CD700>
