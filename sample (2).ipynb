# %%
import cv2
image=cv2.imread('f.png',0)
cv2.imshow('display image',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite('D:/images/f.png',image)
cv2.waitKey(0)

# %%
print("image attributes",image.shape)

# %%
new_image=cv2.rotate(image,cv2.ROTATE_180)
cv2.imshow('display image',new_image)
cv2.waitKey(0)

# %%
import matplotlib.pyplot as plt
images=plt.imread('f.png')
plt.imshow(images)
plt.show()

# %%
image.size

# %%
print("image attributes",images.shape)
# Out:
# image attributes (920, 920, 4)

# %%
#h,w,c=image.shape
#print("Width:",w)
#print("Height:",h)
#print("Channel:",c)

# %%
#code for binary conversion
ret, bw_img = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)
  
bw = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)
  
cv2.imshow("Binary", bw_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
down_width = 300
down_height = 200
down_points = (down_width, down_height)
resized_down = cv2.resize(image, down_points, interpolation= cv2.INTER_LINEAR)
cv2.imshow('Resized Down by defining height and width', resized_down)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
up_width = 600
up_height = 400
up_points = (up_width, up_height)
# resize the image
resized_up = cv2.resize(image, up_points, interpolation = cv2.INTER_LINEAR)
cv2.imshow('Resized Up image by defining height and width', resized_up)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
print('The Shape of the image is:',image.shape)
print('The image as array is:')
print(image)
# Out:
# The Shape of the image is: (920, 920)
# The image as array is:
# [[255 255 255 ... 230 230 230]
#  [255 255 255 ... 230 230 230]
#  [255 255 255 ... 230 230 230]
#  ...
#  [230 230 230 ... 255 255 255]
#  [230 230 230 ... 255 255 255]
#  [230 230 230 ... 255 255 255]]

# %%
from PIL import Image
import numpy as np
w, h = 512, 512
data = np.zeros((h, w, 3), dtype=np.uint8)
data[0:600, 0:600] = [255, 0, 0] # red patch in upper left.
img = Image. fromarray(data, 'RGB')
img. save('my.png')

# %%
images=plt.imread('my.png')
plt.imshow(images)
plt.show()

# %%
import cv2
image=cv2.imread('f.png')
color=cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
cv2.imshow("color types",color)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
color=cv2.cvtColor(image,cv2.COLOR_BGR2HLS)
cv2.imshow("color types",color)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
color=cv2.cvtColor(image,cv2.COLOR_RGB2LAB)
cv2.imshow("color types",color)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
color=cv2.cvtColor(image,cv2.COLOR_RGB2HSV)
cv2.imshow("color types",color)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
color=cv2.cvtColor(image,cv2.COLOR_RGB2YUV)
cv2.imshow("color types",color)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
color=cv2.cvtColor(image,cv2.COLOR_HLS2RGB)
cv2.imshow("color types",color)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
color=cv2.cvtColor(image,cv2.COLOR_BGR2LAB)
cv2.imshow("color types",color)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
import cv2

# read two input images.
# The size of both images must be the same.
img1 = cv2.imread('cctt.jpg')
img2 = cv2.imread('cat2.jpg')

# compute bitwise AND on both images
and_img = cv2.bitwise_and(img1,img2)
# display the computed bitwise AND image
cv2.imshow('Bitwise AND Image', and_img)

or_img = cv2.bitwise_or(img1,img2)
# display the computed bitwise OR image
cv2.imshow('Bitwise OR Image', or_img)

xor_img = cv2.bitwise_xor(img1,img2)
# display the computed bitwise XOR image
cv2.imshow('Bitwise XOR Image', xor_img)

bitwise_not = cv2.bitwise_not(img1,img2)
cv2.imshow("bitwise_not", bitwise_not)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#RGB Channels
from PIL import Image
import matplotlib.pyplot as plt
im1 = Image.open("cat2.jpg")
ch_r,ch_g,ch_b=im1.split()
plt.figure(figsize=(18,6))
plt.subplot(1,3,1);
plt.imshow(ch_r,cmap=plt.cm.Reds);plt.axis('off')
plt.subplot(1,3,2);
plt.imshow(ch_g,cmap=plt.cm.Greens);plt.axis('off')
plt.subplot(1,3,3);
plt.imshow(ch_b,cmap=plt.cm.Blues);plt.axis('off')
plt.tight_layout()
plt.show()

# %%
from PIL import Image,ImageStat
im=Image.open('cat2.jpg')
stat=ImageStat.Stat(im)
print(stat.mean)
# Out:
# [179.4379, 155.81047777777778, 128.9773888888889]

# %%
from PIL import Image,ImageStat
im=Image.open('cat2.jpg')
stat=ImageStat.Stat(im)
print(stat.stddev)
# Out:
# [53.354176856497794, 68.16682903969705, 78.19562881974562]

# %%
from PIL import Image,ImageStat
im=Image.open('cat2.jpg')
stat=ImageStat.Stat(im)
print(stat.median)
# Out:
# [184, 156, 125]

# %%
import numpy as np
from skimage import data
from skimage.viewer import ImageViewer
import matplotlib.pyplot as plt
image =data.horse()  
viewer = ImageViewer(image)
viewer.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3760\2703577070.py:6: FutureWarning: `viewer` is deprecated and will be removed in 0.20. For alternatives, refer to https://scikit-image.org/docs/stable/user_guide/visualization.html
#   viewer = ImageViewer(image)
# []

# %%
#original image
import cv2
import matplotlib.pyplot as plt
from PIL import Image
im = Image.open("flower.png")
plt.imshow(im)
plt.show()

#down sampling
im = Image.open("flower.png")
im = im.resize((im.width//5, im.height//5))
plt.figure(figsize=(15,10))
plt.imshow(im)
plt.show()

#up sampling
import cv2
import matplotlib.pyplot as plt
from PIL import Image
im = Image.open("flower.png")
im = im.resize((im.width*5, im.height*5), Image.NEAREST)
plt.figure(figsize=(15,10))
plt.imshow(im)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
def signaltonoise(a, axis=0, ddof=0):
    a = np.asanyarray(a)
    m = a.mean(axis)
    sd = a.std(axis=axis, ddof=ddof)
    return np.where(sd == 0, 0, m/sd)
im = Image.open("flower.png")
plt.figure(figsize=(20,20))
num_colors_list = [1 << n for n in range(8,0,-1)]
snr_list = []
i = 1
for num_colors in num_colors_list:
    im1 = im.convert('P', palette=Image.ADAPTIVE, colors=num_colors)
    plt.subplot(4,2,i), plt.imshow(im1), plt.axis('off')
    snr_list.append(signaltonoise(im1, axis=None))
    plt.title('Image with # colors = ' + str(num_colors) + ' SNR = ' +
    str(np.round(snr_list[i-1],3)), size=20)
    i += 1
plt.subplots_adjust(wspace=0.2, hspace=0)
plt.show()
