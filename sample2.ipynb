# %%
import cv2
import matplotlib.pyplot as plt
imge1=plt.imread('cctt.jpg')
imge2=plt.imread('cat2.jpg')
plt.imshow(imge1)
plt.show()
plt.imshow(imge2)
plt.show()
addimg=imge1*imge2
plt.imshow(addimg)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
imge1=plt.imread('cctt.jpg')
imge2=plt.imread('cat2.jpg')
plt.imshow(imge1)
plt.show()
plt.imshow(imge2)
plt.show()
addimg=imge1+imge2
plt.imshow(addimg)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
imge1=plt.imread('cctt.jpg')
imge2=plt.imread('cat2.jpg')
plt.imshow(imge1)
plt.show()
plt.imshow(imge2)
plt.show()
addimg=imge1-imge2
plt.imshow(addimg)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
imge1=plt.imread('cctt.jpg')
imge2=plt.imread('cat2.jpg')
plt.imshow(imge1)
plt.show()
plt.imshow(imge2)
plt.show()
addimg=imge2/imge1
plt.imshow(addimg)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7468\3108376035.py:9: RuntimeWarning: divide by zero encountered in true_divide
#   addimg=imge2/imge1
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from PIL import Image
img = Image.open('cctt.jpg')
img.save("D:/cctt.tiff",'TIFF')

# %%
import numpy as np
from skimage import data
import matplotlib.pyplot as plt
# %matplotlib inline
image =data.camera()  
type(image)
np.ndarray

mask = image < 87  
image[mask]=255  
plt.imshow(image, cmap='gray')

# %%
from PIL import Image

# Function to change the image size
def changeImageSize(maxWidth, 
                    maxHeight, 
                    image):
    
    widthRatio  = maxWidth/image.size[0]
    heightRatio = maxHeight/image.size[1]

    newWidth    = int(widthRatio*image.size[0])
    newHeight   = int(heightRatio*image.size[1])

    newImage    = image.resize((newWidth, newHeight))
    return newImage
    
# Take two images for blending them together   
image1 = Image.open("cat2.jpg")
image2 = Image.open("cctt.jpg")

# Make the images of uniform size
image3 = changeImageSize(800, 500, image1)
image4 = changeImageSize(800, 500, image2)

# Make sure images got an alpha channel
image5 = image3.convert("RGBA")
image6 = image4.convert("RGBA")

# Display the images
image5.show()
image6.show()

# alpha-blend the images with varying values of alpha
alphaBlended1 = Image.blend(image5, image6, alpha=.2)
alphaBlended2 = Image.blend(image5, image6, alpha=.4)

# Display the alpha-blended images
alphaBlended1.show()
alphaBlended2.show()

# %%
import cv2
import numpy as np
# Load the image
img = cv2.imread('cctt.jpg')
# Check the datatype of the image
print(img.dtype)
# Subtract the img from max value(calculated from dtype)
img_neg = 255 - img
# Show the image
cv2.imshow('negative',img_neg)
cv2.waitKey(0)
# Out:
# uint8
# -1

# %%
import cv2
image = cv2.imread('cctt.jpg')

y=0
x=0
h=300
w=210
crop_image = image[x:w, y:h]
cv2.imshow("Cropped", crop_image)
cv2.waitKey(0)
# Out:
# -1

# %%
from PIL import Image

#Create an Image Object from an Image
im = Image.open('cctt.jpg')

#Display actual image
im.show()

#left, upper, right, lowe
#Crop
cropped = im.crop((1,2,100,300))

#Display the cropped portion
cropped.show()

#Save the cropped image
cropped.save('d:/images/croppedBeach1.jpg')

# %%
import numpy as np
import cv2
  
# Creating a black image with 3
# channels RGB and unsigned int datatype
img = cv2.imread('cctt.jpg')
  
# Creating rectangle
cv2.rectangle(img, (30, 30), (300, 200), (0, 255, 0), 5)
  
cv2.imshow('dark', img)
  
# Allows us to see image
# until closed forcefully
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Python3 program to draw line
# shape on solid image
import numpy as np
import cv2

# Creating a black image with 3 channels
img = cv2.imread('cctt.jpg')
 

# Creating line
cv2.line(img, (20, 160), (600, 160), (0, 0, 255), 30)

cv2.imshow('dark', img)

# Allows us to see image
# until closed forcefully
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2
  
# Creating a black image with 3
# channels RGB and unsigned int datatype
img = cv2.imread('cctt.jpg')
 

# Creating circle
cv2.circle(img, (200, 200), 80, (255, 0, 0), 3)
  
cv2.imshow('dark', img)
  
# Allows us to see image
# until closed forcefully
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2
  
# Creating a black image with 3
# channels RGB and unsigned int datatype
img = cv2.imread('cctt.jpg')
 
# writing text
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,'GOOD EVENING', (50, 50),
            font, 0.8, (0, 255, 0), 2, cv2.LINE_AA)
  
cv2.imshow('dark', img)
  
# Allows us to see image
# until closed forcefully
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from PIL import Image, ImageOps

img = Image.open('cctt.jpg')
im_invert = ImageOps.invert(img)
im_invert.save('D:/images/negation.jpg', quality=95)
im_invert.show()

# %%
import numpy as np
from skimage import data
import matplotlib.pyplot as plt
# %matplotlib inline
image =data.astronaut() 
plt.imshow(image) 
plt.show()
type(image)
np.ndarray

mask = image < 87  
image[mask]=255  
plt.imshow(image,cmap='gray')

# %%
# importing required libraries of opencv
import cv2

# importing library for plotting
from matplotlib import pyplot as plt

# reads an input image
img = cv2.imread('cat2.jpg',0)

# find frequency of pixels in range 0-255
histr = cv2.calcHist([img],[0],None,[256],[0,256])

# show the plotting graph of an image
plt.plot(histr)
plt.show()

# %%
import cv2
from matplotlib import pyplot as plt
img = cv2.imread('cat2.jpg',0)
  
# alternative way to find histogram of an image
plt.hist(img.ravel(),256,[0,256])
plt.show()

# %%
import numpy as np
from skimage import data
import matplotlib.pyplot as plt
# %matplotlib inline
image =data.coins()  
type(image)
np.ndarray

mask = image < 87  
image[mask]=255  
plt.imshow(image, cmap='gray')

# %%
import numpy as np
from skimage import data
import matplotlib.pyplot as plt
# %matplotlib inline
image =data.coins() 
plt.imshow(image) 
plt.show()
type(image)
np.ndarray

mask = image < 87  
image[mask]=255  
plt.imshow(image,cmap='gray')

# %%
import numpy as np
from skimage import data
import matplotlib.pyplot as plt
# %matplotlib inline
image =data.camera() 
plt.imshow(image) 
plt.show()
type(image)
np.ndarray

mask = image < 87  
image[mask]=255  
plt.imshow(image,cmap='gray')

# %%
import numpy as np
from skimage import data
import matplotlib.pyplot as plt
# %matplotlib inline
image =data.horse() 
plt.imshow(image) 
plt.show()
type(image)
np.ndarray

mask = image < 60 
image[mask]=255
plt.imshow(image,cmap='gray')
